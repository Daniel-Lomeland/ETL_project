# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
beverage_file = "../Data/Mixed_Beverage_Gross_Receipts.csv"

# %%
beverage_df = pd.read_csv(beverage_file)
beverage_df.head(1)
# Out:
#    Taxpayer Number          Taxpayer Name Taxpayer Address Taxpayer City  \
# 0      17606876674  FROGGIES SALOON, INC.      PO BOX 2961        CONROE
#
#   Taxpayer State  Taxpayer Zip  Taxpayer County  Location Number  \
# 0             TX       77305.0              170                1
#
#      Location Name                Location Address       ...        \
# 0  FROGGIES SALOON  13845 CYPRESS NORTH HOUSTON RD       ...
#
#   Inside/Outside City Limits TABC Permit Number  Responsibility Begin Date  \
# 0                          Y           MB479537                 09/08/2000
#
#    Responsibility End Date Obligation End Date Liquor Receipts Wine Receipts  \
# 0               09/07/2009          12/31/2007           17618           178
#
#   Beer Receipts Cover Charge Receipts  Total Receipts
# 0         13342                     0           31138
#
# [1 rows x 24 columns]

# %%
cols = ["Taxpayer Number", "Taxpayer Name", "Taxpayer City", "Taxpayer State", "Taxpayer Zip", "Taxpayer County", "Location Name", "Location Address", "Liquor Receipts", "Wine Receipts", "Beer Receipts", "Total Receipts"]
beverage_clean = beverage_df[cols]
# cols_to_rename = {"Taxpayer Number": "tax_number", 
#                   "Taxpayer Name": "tax_name",
#                   "Taxpayer City": "tax_city", 
#                   "Taxpayer State": "tax_state", 
#                   "Taxpayer Zip": "tax_zip", 
#                   "Taxpayer County": "tax_county", 
#                   "Location Name": "location_name", 
#                   "Location Address": "location_address", 
#                   "Liquor Receipts": "total_liquor", 
#                   "Wine Receipts": "total_wine", 
#                   "Beer Receipts": "total_beer",
#                   "Total Receipts": "total_all"}



# beverage_clean = beverage_clean.rename(columns = cols_to_rename)
# beverage_clean = beverage_clean.set_index("tax_number")
beverage_clean.head(10)
# Out:
#    Taxpayer Number                   Taxpayer Name Taxpayer City  \
# 0      17606876674           FROGGIES SALOON, INC.        CONROE
# 1      12016754884                J R POCKETS CLUB        DENTON
# 2      30116266419                      TEXAS ROSE      HUTCHINS
# 3      12622195266              PLOWMAN & WU, INC.      AMARILLO
# 4      13420337860            TRAVIS PROJECT, INC.         KIRBY
# 5      30116276806                PIZZA GETTI CLUB         LAVON
# 6      11342541874              PHM BEVERAGE, INC.        BOSTON
# 7      17514214240      RED LOBSTER OF TEXAS, INC.       ORLANDO
# 8      17521901177             FOOD CATERING, INC.        DALLAS
# 9      17519330587  CHILI'S BEVERAGE COMPANY, INC.        DALLAS
#
#   Taxpayer State  Taxpayer Zip  Taxpayer County  \
# 0             TX       77305.0              170
# 1             TX       76205.0               61
# 2             TX       75141.0               57
# 3             TX       79106.0              191
# 4             TX       78219.0               15
# 5             TX       75166.0               43
# 6             MA        2109.0                0
# 7             FL       32869.0                0
# 8             TX       75219.0               57
# 9             TX       75240.0               57
#
#                         Location Name                Location Address  \
# 0                     FROGGIES SALOON  13845 CYPRESS NORTH HOUSTON RD
# 1                    J R POCKETS CLUB              1127 FORT WORTH DR
# 2                          TEXAS ROSE    4080 N INTERSTATE HIGHWAY 45
# 3  TEXAS FIREHOUSE SPORTS BAR & GRILL        3333 S COULTER ST STE D1
# 4                         BOOZEHOUNDS           8531 PERRIN BEITEL RD
# 5                    PIZZA GETTI CLUB               7008 HIGHWAY 78 S
# 6                  PHM BEVERAGE, INC.                1111 NE LOOP 410
# 7            RED LOBSTER OF TEXAS INC            2702 PARKER DR STE A
# 8                        FOOD COMPANY               4115 LOMO ALTO DR
# 9                 CHILI'S GRILL & BAR           1000 E US HIGHWAY 377
#
#    Liquor Receipts  Wine Receipts  Beer Receipts  Total Receipts
# 0            17618            178          13342           31138
# 1            20987            193          17484           38664
# 2            12855             42          13517           26414
# 3             5335            483          15691           21509
# 4            25560            277          24131           49968
# 5             9095            253           9666           19014
# 6             4521           1311           3103            8935
# 7            14286           3627           5217           23130
# 8             9341          47468            673           57482
# 9            15621           2045          12706           30372

# %%
beverage_clean.head(10)
# Out:
#    Taxpayer Number                   Taxpayer Name Taxpayer City  \
# 0      17606876674           FROGGIES SALOON, INC.        CONROE
# 1      12016754884                J R POCKETS CLUB        DENTON
# 2      30116266419                      TEXAS ROSE      HUTCHINS
# 3      12622195266              PLOWMAN & WU, INC.      AMARILLO
# 4      13420337860            TRAVIS PROJECT, INC.         KIRBY
# 5      30116276806                PIZZA GETTI CLUB         LAVON
# 6      11342541874              PHM BEVERAGE, INC.        BOSTON
# 7      17514214240      RED LOBSTER OF TEXAS, INC.       ORLANDO
# 8      17521901177             FOOD CATERING, INC.        DALLAS
# 9      17519330587  CHILI'S BEVERAGE COMPANY, INC.        DALLAS
#
#   Taxpayer State  Taxpayer Zip  Taxpayer County  \
# 0             TX       77305.0              170
# 1             TX       76205.0               61
# 2             TX       75141.0               57
# 3             TX       79106.0              191
# 4             TX       78219.0               15
# 5             TX       75166.0               43
# 6             MA        2109.0                0
# 7             FL       32869.0                0
# 8             TX       75219.0               57
# 9             TX       75240.0               57
#
#                         Location Name                Location Address  \
# 0                     FROGGIES SALOON  13845 CYPRESS NORTH HOUSTON RD
# 1                    J R POCKETS CLUB              1127 FORT WORTH DR
# 2                          TEXAS ROSE    4080 N INTERSTATE HIGHWAY 45
# 3  TEXAS FIREHOUSE SPORTS BAR & GRILL        3333 S COULTER ST STE D1
# 4                         BOOZEHOUNDS           8531 PERRIN BEITEL RD
# 5                    PIZZA GETTI CLUB               7008 HIGHWAY 78 S
# 6                  PHM BEVERAGE, INC.                1111 NE LOOP 410
# 7            RED LOBSTER OF TEXAS INC            2702 PARKER DR STE A
# 8                        FOOD COMPANY               4115 LOMO ALTO DR
# 9                 CHILI'S GRILL & BAR           1000 E US HIGHWAY 377
#
#    Liquor Receipts  Wine Receipts  Beer Receipts  Total Receipts
# 0            17618            178          13342           31138
# 1            20987            193          17484           38664
# 2            12855             42          13517           26414
# 3             5335            483          15691           21509
# 4            25560            277          24131           49968
# 5             9095            253           9666           19014
# 6             4521           1311           3103            8935
# 7            14286           3627           5217           23130
# 8             9341          47468            673           57482
# 9            15621           2045          12706           30372

# %%
beverage_clean.to_csv("../Data/cleaned_bev.csv", index = True, header = True)

# %%
beverage_clean = beverage_clean[tax_zip].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a35941392228> in <module>()
# ----> 1 beverage_clean = beverage_clean[tax_zip].astype(int)
#
# NameError: name 'tax_zip' is not defined
